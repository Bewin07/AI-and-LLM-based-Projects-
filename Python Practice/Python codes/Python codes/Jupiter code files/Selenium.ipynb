# %%
hi="hii"

# %%
type(hi)
# Out:
# str

# %%
file=open('untitled.txt',"r")

# %%
print(file.read())
# Out:
# Bewin
# Beno
# daniel
# immanuel

# %%
print(content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(content)
#
# NameError: name 'content' is not defined

# %%
file.close()

# %%
print(content)
# Out:
# Bewin
# Beno
# daniel
# immanuel

# %%
# Open the file
# ↓
# Read all employee names
# ↓
# Convert them into a list
# ↓
# Print:
#     Total Employees: 4
# ↓
# Print each employee name separately

# %%
file.read()
# Out:
# 'Bewin\nBeno\ndavid\nBright\nJoshua\n'

# %%
list_of_employees
# Out:
# ['Bewin', 'Beno', 'david', 'Bright', 'Joshua']

# %%
file= open('employees.txt',"r")
list_of_employees=file.read().strip().split('\n')
print(list_of_employees)
# Out:
# ['Bewin', '', 'Raju', '   ', 'John']

# %%
count=1
for i in range(0,len(list_of_employees)):
    if list_of_employees[i].strip()!="":
        if count<=len(list_of_employees):
            print(f'Employee{count}: {list_of_employees[i]}')
            count+=1
# Out:
# Employee1: Bewin
# Employee2: Raju
# Employee3: John

# %%
print('Total employees:',len(list_of_employees))
print()
for i in list_of_employees:
    print(i)
# Out:
# Total employees: 5
#
# Bewin
# Beno
# david
# Bright
# Joshua

# %%
with open('employees.txt',"r") as file:

    print(file.read())
# Out:
# Bewin
#
# Raju
#
# John

# %%
# print(file.read())

# %%
with open('employees.txt',"w") as file:
    file.write("bewin\nbeno\nbright")

# %%
with open('employees.txt',"a") as file:
    file.write("\npraise the lord")

# %%
pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.7 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.7 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.7 MB 5.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.7 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.7 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 5.2 MB/s  0:00:01
# ...
#
#   Attempting uninstall: urllib3
#
#    ------ --------------------------------- 1/6 [urllib3]
#     Found existing installation: urllib3 2.5.0
# ...

# %%
from selenium import webdriver

driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/")
print(driver.title)
driver.quit()
# Out:
# Python Tutorial

# %%
# Install Selenium
# ↓
# Run browser
# ↓
# Open Google
# ↓
# Read title
# ↓
# Find search box
# ↓
# Type text
# ↓
# Search

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Edge()

driver.get("https://www.google.com")

searchBox = driver.find_element(By.NAME, "q")

searchBox.send_keys("https://www.w3schools.com/python/python_comments.asp")

searchBox.send_keys(Keys.ENTER)

# %%
import os

# %%
files=os.listdir(r"C:\Users\Lenovo\Documents\Jupiter code files")
print(files)
# Out:
# ['.ipynb_checkpoints', 'Access_excel.ipynb', 'Book1.xlsx', 'employees.txt', 'Employee_management_system.ipynb', 'ExcelFile.txt', 'Selenium.ipynb', 'untitled.txt', '~$Book1.xlsx']

# %%
for i in files:
    if 'txt' in i:
        print(i)
# Out:
# employees.txt
# ExcelFile.txt
# untitled.txt

# %%
os.path
# Out:
# <module 'ntpath' from 'C:\\Users\\Lenovo\\anaconda3\\Lib\\ntpath.py'>

# %%
# Open Google
# 2. Search for "W3Schools Python"
# 3. Press Enter
# 4. Print the page title
# 5. Print the current URL
# 6. Close the browser

# %%
import time
driver=webdriver.Chrome()
driver.get("https://www.google.com")
searchBox = driver.find_element(By.NAME, "q")
searchBox.send_keys("https://www.w3schools.com/python/python_comments.asp")
searchBox.send_keys(Keys.ENTER)
time.sleep(3)
print(driver.title)
print(driver.current_url)
driver.quit()
print('done')
# Out:
# https://www.google.com/search?q=https%3A%2F%2Fwww.w3schools.com%2Fpython%2Fpython_comments.asp&sca_esv=ec2bff8bd1e2ef21&source=hp&ei=MHgxaoH3I8Kpvr0PqKql8A4&iflsig=AFdpzrgAAAAAajGGQCWVwbpP1Qgxoi5O3iAwW68800m5&ved=0ahUKEwiBz83BlYyVAxXClK8BHShVCe4Q4dUDCCE&uact=5&oq=https%3A%2F%2Fwww.w3schools.com%2Fpython%2Fpython_comments.asp&gs_lp=Egdnd3Mtd2l6IjRodHRwczovL3d3dy53M3NjaG9vbHMuY29tL3B5dGhvbi9weXRob25fY29tbWVudHMuYXNwSIQBUABYSHAAeACQAQCYAQCgAQCqAQC4AQPIAQD4AQGYAgCgAgCYAwCSBwCgBwCyBwC4BwDCBwDIBwCACAE&sclient=gws-wiz&sei=MXgxap3TIeynvr0P7IXT0Aw
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Jupiter code files'

# %%
os.chdir(r"C:\Users\Lenovo\Documents\main folder")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\imman\\Documents\\Python Practice\\Python codes\\Python codes\\main folder'

# %%
os.chdir(r"C:\Users\imman\Documents\Python Practice\Python codes\Python codes\main folder")

# %%
import os
os.chdir(r"C:\Users\imman\Documents\Python Practice\Python codes\Python codes\main folder")
print(os.getcwd())
folders=os.listdir(os.getcwd())
files_to_store=[]
print(folders)
for i in folders:
    folder_path=os.path.join(os.getcwd(),i)   
    if os.path.isdir(folder_path):
        files=os.listdir(folder_path)
        if files:
            latest_file=max(files,key=lambda file:os.path.getmtime(os.path.join(folder_path,file)))
            files_to_store.append(latest_file)
            print(latest_file)
with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","w") as stfile:
    for i in files_to_store:
        stfile.write("\n"+i)
with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","r") as filee:
    print(filee.read())
# Out:
# C:\Users\Lenovo\Documents\main folder
# ['folder 1', 'folder 2', 'folder 3', 'Store_file.txt']
# third created file.txt
# fourth prepared file in second fold.txt
# first made file in third folder.txt

# %%
with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","w") as stfile:
    for i in files_to_store:
        stfile.write("\n"+i)

# %%
with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","r") as filee:
    print(filee.read())
# Out:
# third created file.txt
# fourth prepared file in second fold.txt
# first made file in third folder.txt

# %%
import os

folders = os.listdir(os.getcwd())

for folder in folders:

    folder_path = os.path.join(os.getcwd(), folder)

    if os.path.isdir(folder_path):

        files = os.listdir(folder_path)

        if files:

            latest_file = max(
                files,
                key=lambda file: os.path.getmtime(
                    os.path.join(folder_path, file)
                )
            )

            print(folder, "->", latest_file)
# Out:
# folder 1 -> third created file.txt
# folder 2 -> third prepared file in second folde.txt
# folder 3 -> first made file in third folder.txt

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/17.7 MB 2.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/17.7 MB 3.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.1/17.7 MB 2.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.6/17.7 MB 2.9 MB/s eta 0:00:06
#    ------- -------------------------------- 3.4/17.7 MB 2.9 MB/s eta 0:00:05
#    -------- ------------------------------- 3.9/17.7 MB 2.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.5/17.7 MB 3.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.2/17.7 MB 3.0 MB/s eta 0:00:05
#    ------------- -------------------------- 6.0/17.7 MB 3.0 MB/s eta 0:00:04
#    -------------- ------------------------- 6.3/17.7 MB 3.0 MB/s eta 0:00:04
# ...

# %%
import os
import mysql.connector
print(os.getcwd())
folders=os.listdir(os.getcwd())
files_to_store=[]
print(folders)
for i in folders:
    folder_path=os.path.join(os.getcwd(),i)   
    if os.path.isdir(folder_path):
        files=os.listdir(folder_path)
        if files:
            latest_file=max(files,key=lambda file:os.path.getmtime(os.path.join(folder_path,file)))
            files_to_store.append(latest_file)
            print(latest_file)
# with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","w") as stfile:
#     for i in files_to_store:
#         stfile.write("\n"+i)
# with open(r"C:\Users\Lenovo\Documents\main folder\Store_file.txt","r") as filee:
#     print(filee.read())

conn=mysql.connector.connect(
    host="localhost",
    user="root",
    password="rootbewin",
    database="automation"
)

cursor=conn.cursor()
for i in files_to_store:
    cursor.execute("Insert into files_table(Filename) values (%s)",(i,))
conn.commit()
cursor.close()
conn.close()
print("file stored successfully")
# Out:
# C:\Users\Lenovo\Documents\main folder
# ['folder 1', 'folder 2', 'folder 3', 'Store_file.txt']
# third created file.txt
# fourth prepared file in second fold.txt
# first made file in third folder.txt
# file stored successfully

# %%
conn=mysql.connector.connect(
    host="localhost",
    user="root",
    password="rootbewin",
    database="automation"
)
cursor=conn.cursor()
cursor.execute("select * from files_table")

# %%
pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/17.7 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/17.7 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/17.7 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/17.7 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.8/17.7 MB 546.6 kB/s eta 0:00:31
#    - -------------------------------------- 0.8/17.7 MB 546.6 kB/s eta 0:00:31
#    -- ------------------------------------- 1.0/17.7 MB 550.8 kB/s eta 0:00:31
#    -- ------------------------------------- 1.0/17.7 MB 550.8 kB/s eta 0:00:31
#    -- ------------------------------------- 1.3/17.7 MB 609.8 kB/s eta 0:00:27
#    --- ------------------------------------ 1.6/17.7 MB 647.3 kB/s eta 0:00:25
# ...

# %%
import os
import mysql.connector

class FileTracker:
    def __init__(self):
        self.latest_files = []
    def get_latest_files(self):
        os.chdir(r"C:\Users\imman\Documents\Python Practice\Python codes\Python codes\main folder")
        current_path = os.getcwd()
        for item in os.listdir(current_path):
            folder_path = os.path.join(current_path, item)
            if os.path.isdir(folder_path):
                files = os.listdir(folder_path)
                if files:
                    latest_file = max(
                        files,
                        key=lambda file: os.path.getmtime(
                            os.path.join(folder_path, file)
                        )
                    )
                    self.latest_files.append(latest_file)

        return self.latest_files

    def store_files(self):
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="rootbewin",
            database="automation"
        )

        cursor = conn.cursor()

        for file_name in self.latest_files:
            cursor.execute(
                "INSERT INTO files_table(filename) VALUES (%s)",
                (file_name,)
            )

        conn.commit()
        cursor.close()
        conn.close()

        print("Files stored successfully")

    def view_files(self):
        print("\nLatest Files Found:")
        print("-" * 30)

        for file_name in self.latest_files:
            print(file_name)

tracker = FileTracker()
tracker.get_latest_files()
tracker.view_files()
tracker.store_files()
# Out:
# Latest Files Found:
# ------------------------------
# third created file.txt
# third prepared file in second folde.txt
# first made file in third folder.txt
# Files stored successfully
